# %% [markdown]
# ### 938. [Range Sum of BST](https://leetcode.com/problems/range-sum-of-bst/)
# Given the root node of a binary search tree and two integers low and high, return the sum of values of all nodes with a value in the inclusive range [low, high].
#
# Example 1:
# Input: root = [10,5,15,3,7,null,18], low = 7, high = 15
# Output: 32
# Explanation: Nodes 7, 10, and 15 are in the range [7, 15]. 7 + 10 + 15 = 32.
#
# Example 2:
# Input: root = [10,5,15,3,7,13,18,1,null,6], low = 6, high = 10
# Output: 23
# Explanation: Nodes 6, 7, and 10 are in the range [6, 10]. 6 + 7 + 10 = 23.
#
#
# Constraints:
#
# The number of nodes in the tree is in the range [1, 2 * 104].
# - 1 <= Node.val <= 105
# - 1 <= low <= high <= 105
# - All Node.val are unique.

# %%
# Solution Travelser
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

    def append_val(self, val):
        print('---')
        self.append_new(TreeNode(val))

    def append_new(self, node):
        _val = node.val

        if _val < self.val:
            if self.left:
                print(f"Moving left to append {_val}")
                self.left.append_new(node)
            else:
                print(f"setting left {_val}")
                self.left = node

        else:
            if self.right:
                print(f"Moving right to append {_val}")
                self.right.append_new(node)
            else:
                print(f"setting right {_val}")
                self.right = node


class Solution:
    def rangeSumBST(self, root, low: int, high: int) -> int:
        stack = []
        res = 0
        stack.append(root)
        
        while stack:
            cur = stack.pop()
            if low <= cur.val <= high:
                res += cur.val
            if cur.left is not None:
                stack.append(cur.left)
            if cur.right is not None:
                stack.append(cur.right)
                
        return res

# %%
def insert(root, value):
    newnode = TreeNode(value)

    # Pointer start traversing from root and downward path
    # to search insert where
    cur = root

    # Pointer maintains the trailing pointer of cur
    after = None

    while cur is not None:
        after = cur
        if value < cur.val:
            cur = cur.left
        else:
            cur = cur.right

    # If root is None, The new node is the root
    if after is None:
        after = newnode
    elif value < after.val: # left node
        after.left = newnode
    else: # right node
        after.right = newnode

    # Return pointer where the node is inserted
    return after

# %%
root = [10, 5, 15, 3, 7, 13, 18, 1, None, 6]
low = 6
high = 10
tree = None
for value in root:
    if value is None:
        continue
    if tree is None:
        tree = TreeNode(value)
    else:
        tree.append_val(value)
    # insert(tree, value)
print(f"--- Range SUM OF BST: {Solution().rangeSumBST(tree, low, high)} ---")
# Out:
# ---
# setting left 5
# ---
# setting right 15
# ---
# Moving left to append 3
# setting left 3
# ---
# Moving left to append 7
# setting right 7
# ---
# Moving right to append 13
# setting left 13
# ---
# Moving right to append 18
# setting right 18
# ---
# Moving left to append 1
# Moving left to append 1
# setting left 1
# ---
# Moving left to append 6
# Moving right to append 6
# setting left 6
# --- Range SUM OF BST: 23 ---
